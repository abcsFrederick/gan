# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../lists/Data_Entry_2017.csv')

# %%
df.head()
# Out:
#               index                   label  follow_up  ID  age gender view  \
# 0  00000001_000.png            Cardiomegaly          0   1   58      M   PA
# 1  00000001_001.png  Cardiomegaly|Emphysema          1   1   58      M   PA
# 2  00000001_002.png   Cardiomegaly|Effusion          2   1   58      M   PA
# 3  00000002_000.png              No Finding          0   2   81      M   PA
# 4  00000003_000.png                  Hernia          0   3   81      F   PA
#
#    oresx  oresy  ospacingx   ospacingy   misc
# 0   2682   2749      0.143       0.143    NaN
# 1   2894   2729      0.143       0.143    NaN
# 2   2500   2048      0.168       0.168    NaN
# 3   2500   2048      0.171       0.171    NaN
# 4   2582   2991      0.143       0.143    NaN

# %%
df.groupby('label').count().sort_values(by='index', ascending=False)
# Out:
#                                                     index  follow_up     ID  \
# label
# No Finding                                          60361      60361  60361
# Infiltration                                         9547       9547   9547
# Atelectasis                                          4215       4215   4215
# Effusion                                             3955       3955   3955
# Nodule                                               2705       2705   2705
# Pneumothorax                                         2194       2194   2194
# Mass                                                 2139       2139   2139
# Effusion|Infiltration                                1603       1603   1603
# Atelectasis|Infiltration                             1350       1350   1350
# Consolidation                                        1310       1310   1310
# Atelectasis|Effusion                                 1165       1165   1165
# ...
